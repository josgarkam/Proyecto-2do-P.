# %% [markdown]
# <a href="https://colab.research.google.com/github/josgarkam/Proyecto-2do-P./blob/main/bot_telegram_GOLD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install python-telegram-bot

# %%
# LIBRERIAS
from vuelo import Vuelo
from telegram.ext import (Updater, CommandHandler, MessageHandler, Filters, RegexHandler, ConversationHandler, CallbackQueryHandler)

##########################################################################################

# BASE DE DATOS DE VUELOS
v1 = Vuelo("tame","GUAYAQUIL","QUITO", "40 minutos",150,"f1","f2","0","/GYEUIO","Aeropuerto_José_Joaquín_de_Olmedo_de_Guayaquil","Aeropuerto Internacional de Quito")
v2 = Vuelo("Latan","GUAYAQUIL","QUITO","120 minutos",145,"f1","f2","0","/GYEUIO","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional de Quito")
v3 = Vuelo("Latan","GUAYAQUIL","CUENCA", "90 minutos",120,"f1","f2","0","/GYECUE","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Mariscal Lamar")
v4 = Vuelo("Latan","GUAYAQUIL","MANTA", "60 minutos",130,"f1","f2","0","/GYEMEC","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Eloy Alfaro Manta")    
v5 = Vuelo("Latan","GUAYAQUIL","ISLA BALTRA","145 minutos",240,"f1","f2","0","/GYEGPS","Aeropuerto José Joaquín de Olmedo de Guayaquil","El aeropuerto Seymour") 
v6 = Vuelo("Tame","GUAYAQUIL", "BUENOS AIRES","330 minutos",800,"f1","f2","0","/GYEEZE","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Buenos Aires Jorge Newbery") 
v7 = Vuelo("Latan","GUAYAQUIL", "CÓRDOVA", "360 minutos",600,"f1","f2","0","/GYECOR", "Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional José María Córdova")
v8 = Vuelo("AZUL LINHAS","GUAYAQUIL","SAN PABLO", "400 minutos",700,"f1","f2","0","/GYEGRU","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Guaruhos,San Pablo")
v9 = Vuelo("FLYBE","GUAYAQUIL","CIUDAD DE MEXICO","600 minutos",500,"f1","f2","0","/GYEMEX","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Benito Juarez")
v10 = Vuelo("TAME","QUITO","BOGOTA","600 minutos",850,"f1","f2","0","/UIOBOG","Aeropuerto Internacional El Nuevo Dorado","Aeropuerto Internacional de Quito")
v11 = Vuelo("LAN ECUADOR","QUITO","MEXICO","700 minutos",160,"f1","f2","0","/UIOMEX","Aeropuerto Internacional de Quito","Aeropuerto Internacional Benito Juarez ")
v12 = Vuelo("AIR CANADA","QUITO","CANADA","900 minutos",1200,"f1","f2","0","/UIOYYZ","Aeropuerto Internacional de Quito","Aeropuerto Internacional Toronto Pearson" )
v13 = Vuelo("AIR EUROPE","QUITO","MOSCU","700 minutos",7250,"f1","f2","0","/UIOSVO","Aeropuerto Internacional de Quito","Aeropuerto Internacional de Moscú-Sheremétievo")
v14 = Vuelo("AIR EUROPE","QUITO","MURCIA","550 minutos,",3400,"f1","f2","0","/UIORMU","Aeropuerto Internacional de Quito","Aeropuerto Internacional de la Región de Murcia")
v15 = Vuelo("AVIANCA","CUENCA","RIO DE JANEIRO","500 minutos",809,"f1","f2","0","/CUEGIG","Aeropuerto Internacional Mariscal Lamar","Aeropuerto Internacional Galeao Antonio Carlos Jobim")
v16 = Vuelo("LAN ECUADOR","CUENCA","CARACAS","400 minutos",700,"f1","f2","0","/CUECCS","Aeropuerto Internacional Mariscal Lamar","Aeropuerto Internacional Simon Bolivar")
v17 = Vuelo("TAME","CUENCA","MONTERREY","550 minutos",650,"f1","f2","0","/CUEMTY","Aeropuerto Internacional Mariscal Lamar","Aeropuerto Gen Mariano Escobeado")
v18 = Vuelo("TAME","CUENCA","CIUDAD DE MEXICO","660 minutos",560,"f1","f2","0","/CUEMEX","Aeropuerto Internacional Mariscal Lamar","Aeropuerto Internacional Benito Juarez ")
v19 = Vuelo("LAN ECUADOR","CUENCA","QUITO","45 minutos",200,"f1","f2","0","/CUEUIO","Aeropuerto Internacional Mariscal Lamar","Aeropuerto Internacional de Quito")
v20 = Vuelo("AMERICAN AIRLINES","GUAYAQUIL","MIAMI","500 minutos",540,"f1","f2","0","/GYEMIA","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Miami")
v21 = Vuelo("AIR EUROPE","GUAYAQUIL","MENORCA","555 minutos",1020,"f1","f2","0","/GYEMAH","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto de Menorca")
v22 = Vuelo("LAN ECUADOR","GUYAYAQUIL","MEDALLIN","400 minutos",700,"f1","f2","0","/GYEMDE","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Jose Maria Cordova")
v23 = Vuelo("AIR EUROPE","GUAYAQUIL","MOSCU","590 minutos",8200,"f1","f2","0","/GYESVO","Aeropuerto José Joaquín de Olmedo de Guayaquil","aeropuerto de Domodédovo")
v24 = Vuelo("AIR CANADA","GUAYAQUIL","MONTREAL","540 minutos",1055,"f1","f2","0","/GYEYUL","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Pierre Elliott Trudeau")
v25 = Vuelo("LAN ECUADOR","MANTA","GUAYAQUIL","40 minutos",120,"f1","f2","0","/MECGYE","Aeropuerto Internacional Eloy Alfaro ","Aeropuerto José Joaquín de Olmedo de Guayaquil")
v26 = Vuelo("LAN ECUADOR","MANTA","QUITO","80 minutos",160,"f1","f2","0","/MECUIO","Aeropuerto Internacional Eloy Alfaro","Aeropuerto Internacional de Quito")
v27 = Vuelo("LAN ECUADOR","MANTA","CUENCA","85 minutos",95,"f1","f2","0","/MECCUE","Aeropuerto Internacional Eloy Alfaro","Aeropuerto Internacional Mariscal Lamar")
v28 = Vuelo("LAN ECUADOR","GALAPAGOS","GUAYAQUIL","90 minutos",600,"f1","f2","0","/GPSGYE","Aeropuerto Ecológico de Galápagos","Aeropuerto José Joaquín de Olmedo de Guayaquil")
v29 = Vuelo("LAN ECUADOR","GALAPAGOS","CUENCA","90 minutos",125,"f1","f2","0","/GPSCUE","Aeropuerto Ecológico de Galápagos","Aeropuerto Internacional Mariscal Lamar")
v30 = Vuelo("LAN ECUADOR","GALAPAGOS","QUITO","89 minutos",750,"f1","f2","0","/GPSUIO","Aeropuerto Ecológico de Galápagos","Aeropuerto Internacional de Quito")
v31 = Vuelo("AIR CHINA","GUAYAQUIL","PEKIN","900 minutos",3400,"f1","f2","0","/GYEPEK","Aeropuerto José Joaquín de Olmedo de Guayaquil","El Aeropuerto Internacional de Pekín-Capital")
v32 = Vuelo("AIR CHINA","CUENCA","PEKIN","990 minutos",3500,"f1","f2","0","/CUEPEK","Aeropuerto Internacional Mariscal Lamar","El Aeropuerto Internacional de Pekín-Capital")
v33 = Vuelo("LAN ECUADOR","CUENCA","BOGOTA","80 minutos",980,"f1","f2","0","/CUEBOG","Aeropuerto Internacional Mariscal Lamar","Aeropuerto Internacional El Nuevo Dorado")
v34 = Vuelo("LAN ECUADOR","CUENCA","MANTA","50 minutos",170,"f1","f2","0","/CUEMEC","Aeropuerto Internacional Mariscal Lamar","Aeropuerto Internacional Eloy Alfaro")
v35 = Vuelo("AIR JAPON","GUAYAQUIL","NARITA","500 minutos",2430,"f1","f2","0","/GYENRT","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional de Narita")
v36 = Vuelo("AMERICAN AIRLINES","GUAYAQUIL","NUEVA YORK","200 minutos",490,"f1","f2","0","/GYEEWR","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Jhon F Kennedy Nueva York")
v37 = Vuelo("AMERICAN AIRLINES","CUENCA","NUEVA YORK","230 minutos",520,"f1","f2","0","/CUEEWR","Aeropuerto Internacional Mariscal Lamar","Aeropuerto Internacional Jhon F Kennedy Nueva York")
v38 = Vuelo("AIR EUROPE","GUAYAQUIL","AUSTRALIA","900 minutos",14200,"f1","f2","0","/GYEMEL","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Kingsford Smith")
v39 = Vuelo("LAN ECUADOR","GUAYAQUIL","LIMA ","99 minutos",520,"f1","f2","0","/GYELIM","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto Internacional Jorge Chávez")
v40 = Vuelo("AIR EUROPE","GUAYAQUIL","UCRANIA","500 minutos",5500,"f1","f2","0","/GYEODS","Aeropuerto José Joaquín de Olmedo de Guayaquil","Aeropuerto de Odesa Central")

##########################################################################################

#VARIABLES GLOBALES
ncliente=" "
acliente=" "
av = False 
avi=False 
v=[]
of=[]
ff=[]
vul=Vuelo 
c=""
cr=""
tt=0
n=0

of.append(v1)
of.append(v2)
of.append(v3)
of.append(v4)
of.append(v5)
of.append(v6)
of.append(v7)
of.append(v8)
of.append(v9)
of.append(v10)
of.append(v11)
of.append(v12)
of.append(v13)
of.append(v14)
of.append(v15)
of.append(v16)
of.append(v17)
of.append(v18)
of.append(v19)
of.append(v20)
of.append(v21)
of.append(v22)
of.append(v23)
of.append(v24)
of.append(v25)
of.append(v26)
of.append(v27)
of.append(v28)
of.append(v29)
of.append(v30)
of.append(v31)
of.append(v32)
of.append(v33)
of.append(v34)
of.append(v35)
of.append(v36)
of.append(v37)
of.append(v38)
of.append(v39)
of.append(v40)

##########################################################################################

TOKEN = "1648931352:AAHpfb9_Kaqw8oeWTlihHbyf5Ze_Jn4vlqI"  # TOKEN DE TELEGRAM

# COMANDOS DE INICIO

def start(update,context):
    update.message.reply_text("BIENVENIDO SERÁ UN PLACE ATENDERLO EN \n\n\n")
    update.message.reply_text("AGENCIA DE VIAJES BOT \n")
    update.message.reply_text("-PARA ACCEDER A LA LISTA DE VUELOS PRESIONE \t/LIST"
                              +"\n-PARA ACCEDER A LA OPCIÓN DE BUSCAR PRESIONE \t/SEARCHD"
                              +"\n-PARA COMPRAR SU VUELO DE IDA PRESIONE \t/BUY_TICKET"
                              +"\n-PARA COMPRAR SU VUELO DE IDA Y VUELA PRESIONE \t/BUYRT_TICKET"
                              +"\n-PARA VISUALISAR UNA LISTA DE COMANDO PRESIONE \t/HELP")
  

##########################################################################################
def Listar(update,context):
    l=0
    update.message.reply_text("-Te muestro todos los vuelos  :")
    for t in of:
        l=l+1
        update.message.reply_text("____ Vuelo #"+str(l)+" _____")
        update.message.reply_text("Origen: " +t.origen+ "\nDestino: " + t.destino + "\nPrecio: " + str(t.precio) 
        + "$" + "\nDuracion: " + t.duracion + "\nAerolinea: " + t.aerolinea + "\nAeropuerto de salida: "
        + t.aero1 + "\nAeropuerto de llegada: " + t.aero2)
    update.message.reply_text("\n- /regresar")


##########################################################################################
def bc(update,context):
    update.message.reply_text("-Para buscar viajes por ciudad ingrese /Busquedaciudad(ciudad)")
    update.message.reply_text("\n -Ejemplo:  /Busquedaciudad guayaquil")
    update.message.reply_text("-Para buscar viajes por código IATA ingrese /Busquedaiata(ciudad)")
    update.message.reply_text("\n -Ejemplo:  /Busquedaiata /GYEUIO")
    update.message.reply_text("-Para buscar viajes por aeropuerto ingrese /Busquedaaeropuerto(ciudad)")
    update.message.reply_text("\n -Ejemplo:  /Busquedaaeropuerto jose juaquin de olmedo")


##########################################################################################
def Busquedaciudad(update,context):
    global av  #bv
    args=context.args
    if len(args) == 0:
       bc(update,context)
    else:
        u=args[0]
        a = u.upper()
        for h in of:
            if a == h.origen:
                update.message.reply_text("Origen :" + h.origen + "\nAeropuerto de salida: "
                + h.aero1 + "\nDestino :" + h.destino +  "\nAeropuerto de llegada: " + h.aero2 
                + "\nPrecio:" + str(h.precio) + "$" + "\nDuracion:" + h.duracion + "\nAerolinea:" 
                + h.aerolinea)
                bv=True
                
        if av==False: #bv
                time.sleep(1)
                update.message.reply_text("Lo sentimos no se encontro nada ....")
                bc(update,context)
    update.message.reply_text("\n- /regresar")


##########################################################################################
def Busquedaiata(update,context):
    global av
    args=context.args
    if len(args) == 0:
       bc(update,context)
    else:
        u=args[0]
        a = u.upper()
        for h in of:
            if a == h.cod:
                update.message.reply_text("Origen :" + h.origen + "\nAeropuerto de salida: "
                + h.aero1 + "\nDestino :" + h.destino +  "\nAeropuerto de llegada: " + h.aero2 
                + "\nPrecio:" + str(h.precio) + "$" + "\nDuracion:" + h.duracion + "\nAerolinea:" 
                + h.aerolinea)
                av=True
                
        if av==False:
                time.sleep(1)
                update.message.reply_text("Lo sentimos no se encontro nada ....")
                bc(update,context)
    update.message.reply_text("\n- /regresar")    

##########################################################################################
def Busquedaaeropuerto(update,context):
    l=0
    update.message.reply_text("-Aeropuertos:  ")
    for t in of:
      l=l+1
      update.message.reply_text(" Aeropuerto de salida: "+ t.aero1 + "\nAeropuerto de llegada: " 
                                + t.aero2 + "\nDesde " + t.origen + "\nHasta " + t.destino 
                                + "\nPrecio: " + str(t.precio)+"$")# Presentar una lista de todos los aeropuertos
    update.message.reply_text("\n- /regresar")


##########################################################################################
def Ida(update,context):
    global avi, pm #idv
    avi = False
    pm=False
    update.message.reply_text("Para elegir un vuelo solo de click en el comando ejemplo /GYEUIO")
    for b in of:
     update.message.reply_text("Origen: "+b.origen+ "\nAeropuerto de salida: "+b.aero1 + "\nDestino: "+b.destino 
     + "\nAeropuerto de llegada: " + b.aero2 +"\nAerolínea: "+b.aerolinea+"\nPrecio: "+str(b.precio)+"$"
     +"\nDuracion: "+b.duracion+"\n" + b.cod)


##########################################################################################
def  IdaVuelta(update,context):
    global avi, pm
    avi=True
    pm=True
    update.message.reply_text("Para elegir un vuelo solo de click en el comando ejemplo /GYEUIO")
    for b in of:

        update.message.reply_text("Origen: "+b.origen+ "\nAeropuerto de salida: "+b.aero1 + "\nDestino: "+b.destino 
        + "\nAeropuerto de llegada: " + b.aero2 +"\nAerolínea: "+b.aerolinea+"\nPrecio: "+str(b.precio)+"$"
        +"\nDuracion: "+b.duracion+"\n" + b.cod) 


##########################################################################################
def  Reserva(update,context):
    i=0
    global c, cr, tt ,n ,vul,avi, ncliente,acliente 
    args=context.args
    if len(args)==0:
        update.message.reply_text("!ingrese una cedula !!  /cedulaR 1234567890 ")    
    else:
        Reserva = args[0]
        if len(Reserva)==10 and Reserva.isdigit():
            i=Reserva
            if i==cr:
                update.message.reply_text("_____________________DATOS DE SU VUELO________________________\n")
                update.message.reply_text("___________________________________________________________________")
                update.message.reply_text("Su viaje con origen en: " + vul.origen + "\nDestino: " + vul.destino + "\nDuracion: " + vul.duracion 
                                          + "\nFecha de Ida: " + vul.fecha1 + "\nPrecio: "+str(vul.precio)+"$"+"\n Numero de asientos: " +str(vul.npersona)
                                          + "\nAeropuerto de salida: "+ vul.aero1 + "\nAeropuerto de llegada: "+ vul.aero2)


                update.message.reply_text("Nombre del cliente:  " + ncliente +" "+ acliente)
                update.message.reply_text("Número de Cedula:  "+c)
                update.message.reply_text("Su total a cancelar es de " + str(tt) + "$")
                update.message.reply_text("\n\n\nGRACIAS POR ELEJIRNOS, FELIZ VUELO")
                update.message.reply_text("\n- /regresar")

            else: 
              update.message.reply_text("Su cedula no tiene vuelos registrados")
              i=0
              update.message.reply_text("\n- /regresar")
        else:
             update.message.reply_text("! ingrese cedula valida de 10 digitos !")
             update.message.reply_text("ingrese su cedula con /cedulaR 0123456789")
             Reserva(update,context,args)

##########################################################################################
def ListarIATA(update,context):# Presentar una lista de todos los códigos IATA
    l=0
    update.message.reply_text("-Te muestro todos los vuelos:  ")
    for t in of:
      l=l+1
      update.message.reply_text( "vuelo #" +str(l)+"\nDesde " + t.origen + " hasta " + t.destino + " IATA: "+ t.cod)


##########################################################################################
def ayuda(update,context):# LISTA CON LOS COMANDOS MAS RELEVANTES DEL BOT
      
        update.message.reply_text("Lista de comandos implementados: "+"\n\n/start - Comando de inicio"
                              +"\n\n/HELP- Consulta la lista de comandos implementados y la descripcion de estos"
                              +"\n\n/LIST - Lista todos los vuelos disponibles "
                              +"\n\n/SEARCHD  - Busca viajes por Origen"
                              +"\n\n/BUY_TICKET - Permite comprar Vuelos de Ida"
                              +"\n\n/BUYRT_TICKET - Permite comprar vuelos de Ida y Vuelta"
                              +"\n\n/LIST_IATA - Lista de los códigos IATA de los Vuelos"
                              +"\n\n/Reserva - Para ver la reserva del vuelo")



###########__________________________________METODOS DE DATOS____________________________________############# 

##########################################################################################

def Fecha1(update,context):
    global  vul, avi
    args=context.args
    f=args[0]
    vul.fecha1=f
    if avi== False:
       update.message.reply_text("A continuacion escriba: /asiento (número de asientos por persona a reservar)\n -Ejemplo /asiento 2")

##########################################################################################

def Fecha2(update,context):
    global vul
    args=context.args
    f=args[0]
    vul.fecha2=f
    update.message.reply_text("A continuacion escriba: /asiento (número de asientos por persona a reservar)\n -Ejemplo /asiento 2")

##########################################################################################


def nasiento(update,context):
    global vul,tt,n,pm
    args=context.args
    if len(args)==0:
        update.message.reply_text("ingresa un numero de asientos: /asiento (número de asientos por persona a reservar)\n -Ejemplo /asiento 2")
    else:
      n = int(args[0])
      vul.npersona=n
      p=int(str(vul.precio))
      tt=p*n
      update.message.reply_text("-Para ingresar su nombre /Nombre")
      update.message.reply_text("Ejemplo /Nombre Pepe")



##########################################################################################

def Nombre(update,context):
    global ncliente
    args=context.args
    if len(args) == 0:
        update.message.reply_text("No puede dejar vacio su Apellido")
        nom(update,context)
    else:
        ncliente=args[0]
        update.message.reply_text("-Para ingresar su nombre /Apellido")
        update.message.reply_text("Ejemplo /Apellido Grillo")   

##########################################################################################

def nom(update,context):
    update.message.reply_text("-Para ingresar su nombre /Nombre Pepe")        

##########################################################################################

def Apellido(update,context):
    global acliente
    args=context.args
    if len(args) == 0:
        update.message.reply_text("No puede dejar vacio su Apellido")
        ape(update,context)
    else:
        acliente=args[0]
        update.message.reply_text("ingrese su cedula con /cedula 0000000000000")              

##########################################################################################

def ape(update,context):
    update.message.reply_text("-Para ingresar su nombre /Apellido Grillo")

##########################################################################################

def id(update,context):
    global c, cr,tt ,n ,vul, avi, ncliente,acliente
    args=context.args
    if len(args)==0:
        update.message.reply_text("Por favor ingrese un número de Cedula como:  /cedula 1234567890 ")
    else:
        id = args[0]
        if len(id)==10 and id.isdigit():
            c=id
            if  avi == False:
                update.message.reply_text("_____________________DATOS DE SU VUELO________________________\n")
                update.message.reply_text("___________________________________________________________________")
                update.message.reply_text("Su viaje con origen en: " + vul.origen + "\nDestino: " + vul.destino + "\nDuracion: " + vul.duracion 
                                              + "\nFecha de Ida: " + vul.fecha1 + "\nPrecio: "+str(vul.precio)+"$"+"\n Numero de asientos: " +str(vul.npersona)
                                              + "\nAeropuerto de salida: "+ vul.aero1 + "\nAeropuerto de llegada: "+ vul.aero2)
            if  avi == True:
                update.message.reply_text("________________________DATOS DE SU VUELO________________________\n")
                update.message.reply_text("___________________________________________________________________")
                update.message.reply_text("Origen: " + vul.origen + "\nDestino: " + vul.destino + "\nDuracion: " + vul.duracion 
                                         + "\nFecha de Ida: " + vul.fecha1 + "\nFecha de Regreso: " + vul.fecha2 + "\nPrecio Base: "
                                         +str(vul.precio)+"$"+"\nNumero de asientos: "+str(vul.npersona) + "\nAeropuerto de salida: " 
                                         + vul.aero1 + "\nAeropuerto de llegada: "+ vul.aero2)
                pi = vul.precio * 2
                vul.precio = pi
                tt = n * vul.precio
                update.message.reply_text("Precio por Ida y vuelta: " + str(pi) + "$")

            cr=c
            update.message.reply_text("Nombre del cliente:  " + ncliente +" "+ acliente)
            update.message.reply_text("Número de Cedula:  "+c)
            update.message.reply_text("Su total a cancelar es de: " + str(tt) + "$")

            update.message.reply_text("\n\n\nGRACIAS POR ELEJIRNOS, DISFRUTE SU VUELO")
            update.message.reply_text("\n- /regresar")

        else:
             update.message.reply_text("! ingrese cedula valida de 10 digitos !")
             update.message.reply_text("ingrese su cedula con /cedula 0123456789")
             id(update,context,args)


##########################################################################################

#METODO DE COMANDOS INVALIDOS
def mensaje_nocomando(update,context):
    update.message.reply_text("SU COMANDO ES INVALIDO, POR FAVOR INGRESE DE NUEVO."
                              +"\n\nPARA VER LA LISTA DE COMANDOS IMPORTANTES PRESIONA /HELP")  

##########################################################################################


###################______________________METODOS PARA LOS CÓDIGOS IATA_______________________####################


##############################################################################################################1


def GYEUIO(update,context):
    global vul, avi
    vul =Viaje(of[0].aerolinea,of[0].origen,of[0].destino,of[0].duracion,of[0].precio,of[0].fecha1,of[0].fecha2,of[0].npersona,of[0].cod,of[0].aero1, of[0].aero2)
    update.message.reply_text(
        "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################2  


def GYEUIO(update,context):
    global vul, avi
    vul =Viaje(of[1].aerolinea,of[1].origen,of[1].destino,of[1].duracion,of[1].precio,of[1].fecha1,of[1].fecha2,of[1].npersona,of[1].cod,of[1].aero1, of[1].aero2)
    update.message.reply_text(
      "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################3  


def GYECUE(update,context):
    global vul, avi
    vul =Viaje(of[2].aerolinea,of[2].origen,of[2].destino,of[2].duracion,of[2].precio,of[2].fecha1,of[2].fecha2,of[2].npersona,of[2].cod,of[2].aero1, of[2].aero2)
    update.message.reply_text(
 "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################4  


def GYEMEC(update,context):
    
    global vul,  avi
    vul =Viaje(of[3].aerolinea,of[3].origen,of[3].destino,of[3].duracion,of[3].precio,of[3].fecha1,of[3].fecha2,of[3].npersona,of[3].cod,of[3].aero1, of[3].aero2 )
    update.message.reply_text(
        "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################5  


def GYEGPS(update,context):
    global vul, avi
    vul =Viaje(of[4].aerolinea,of[4].origen,of[4].destino,of[4].duracion,of[4].precio,of[4].fecha1,of[4].fecha2,of[4].npersona,of[4].cod,of[4].aero1, of[4].aero2)
    update.message.reply_text(
   "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################6  


def GYEEZE(update,context):
    global vul,  avi
    vul =Viaje(of[5].aerolinea,of[5].origen,of[5].destino,of[5].duracion,of[5].precio,of[5].fecha1,of[5].fecha2,of[5].npersona,of[5].cod,of[5].aero1, of[5].aero2)
    update.message.reply_text(
      "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia

##############################################################################################################7  

def GYECOR(update,context):
    global vul,  avi
    vul =Viaje(of[6].aerolinea,of[6].origen,of[6].destino,of[6].duracion,of[6].precio,of[6].fecha1,of[6].fecha2,of[6].npersona,of[6].cod,of[6].aero1, of[6].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia

##############################################################################################################8 

def GYEGRU(update,context):
    global vul,  avi
    vul =Viaje(of[7].aerolinea,of[7].origen,of[7].destino,of[7].duracion,of[7].precio,of[7].fecha1,of[7].fecha2,of[7].npersona,of[7].cod,of[7].aero1, of[7].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################9  


def GYEMEX(update,context):
    global vul,  avi
    vul =Viaje(of[8].aerolinea,of[8].origen,of[8].destino,of[8].duracion,of[8].precio,of[8].fecha1,of[8].fecha2,of[8].npersona,of[8].cod,of[8].aero1, of[8].aero2)
    update.message.reply_text(
    "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################10 


def UIOBOG(update,context):
    global vul,  avi
    vul =Viaje(of[9].aerolinea,of[9].origen,of[9].destino,of[9].duracion,of[9].precio,of[9].fecha1,of[9].fecha2,of[9].npersona,of[9].cod,of[9].aero1, of[9].aero2)
    update.message.reply_text(
      "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################11 


def UIOMEX(update,context):
    global vul,  avi
    vul =Viaje(of[10].aerolinea,of[10].origen,of[10].destino,of[10].duracion,of[10].precio,of[10].fecha1,of[10].fecha2,of[10].npersona,of[10].cod,of[10].aero1, of[10].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################12  


def UIOYYZ(update,context):
    global vul,  avi
    vul =Viaje(of[11].aerolinea,of[11].origen,of[11].destino,of[11].duracion,of[11].precio,of[11].fecha1,of[11].fecha2,of[11].npersona,of[11].cod,of[11].aero1, of[11].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################13 


def UIOSVO(update,context):
    global vul,  avi
    vul =Viaje(of[12].aerolinea,of[12].origen,of[12].destino,of[12].duracion,of[12].precio,of[12].fecha1,of[12].fecha2,of[12].npersona,of[12].cod,of[12].aero1, of[12].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################14  


def UIORMU(update,context):
    global vul,  avi
    vul =Viaje(of[13].aerolinea,of[13].origen,of[13].destino,of[13].duracion,of[13].precio,of[13].fecha1,of[13].fecha2,of[13].npersona,of[13].cod,of[13].aero1, of[13].aero2)
    update.message.reply_text(
      "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################15 


def CUEGIG(update,context):
    global vul,  avi
    vul =Viaje(of[14].aerolinea,of[14].origen,of[14].destino,of[14].duracion,of[14].precio,of[14].fecha1,of[14].fecha2,of[14].npersona,of[14].cod,of[14].aero1, of[14].aero2)
    update.message.reply_text(
     "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################16 


def CUECCS(update,context):
    global vul,  avi
    vul =Viaje(of[15].aerolinea,of[15].origen,of[15].destino,of[15].duracion,of[15].precio,of[15].fecha1,of[15].fecha2,of[15].npersona,of[15].cod,of[6].aero1, of[15].aero2)
    update.message.reply_text(
     "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################17 


def CUEMTY(update,context):
    global vtt,  avi
    vul =Viaje(of[16].aerolinea,of[16].origen,of[16].destino,of[16].duracion,of[16].precio,of[16].fecha1,of[16].fecha2,of[16].npersona,of[16].cod,of[16].aero1, of[16].aero2)
    update.message.reply_text(
        "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################18 


def CUEMEX(update,context):
    global vul,  avi
    vul =Viaje(of[17].aerolinea,of[17].origen,of[17].destino,of[17].duracion,of[17].precio,of[17].fecha1,of[17].fecha2,of[17].npersona,of[17].cod,of[17].aero1, of[17].aero2)
    update.message.reply_text(
     "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################19 


def CUEUIO(update,context):
    global vul,  avi
    vul =Viaje(of[18].aerolinea,of[18].origen,of[18].destino,of[18].duracion,of[18].precio,of[18].fecha1,of[18].fecha2,of[18].npersona,of[18].cod,of[18].aero1, of[18].aero2)
    update.message.reply_text(
        "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################20 


def  GYEMIA(update,context):
    global vul,  avi
    vul =Viaje(of[19].aerolinea,of[19].origen,of[19].destino,of[19].duracion,of[19].precio,of[19].fecha1,of[19].fecha2,of[19].npersona,of[19].cod,of[19].aero1, of[19].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################21 


def GYEMAH(update,context):
    global vul,  avi
    vul =Viaje(of[20].aerolinea,of[20].origen,of[20].destino,of[20].duracion,of[20].precio,of[20].fecha1,of[20].fecha2,of[20].npersona,of[20].cod,of[20].aero1, of[20].aero2)
    update.message.reply_text(
      "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################22 


def GYEMDE(update,context):
    global vul,  avi
    vul =Viaje(of[21].aerolinea,of[21].origen,of[21].destino,of[21].duracion,of[21].precio,of[21].fecha1,of[21].fecha2,of[21].npersona,of[21].cod,of[21].aero1, of[21].aero2)
    update.message.reply_text(
    "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################23 


def GYESVO(update,context):
    global vul,  avi
    vul =Viaje(of[22].aerolinea,of[22].origen,of[22].destino,of[22].duracion,of[22].precio,of[22].fecha1,of[22].fecha2,of[22].npersona,of[22].cod,of[22].aero1, of[22].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################24 


def GYEYUL(update,context):
    global vul, avi
    vul =Viaje(of[23].aerolinea,of[23].origen,of[23].destino,of[23].duracion,of[23].precio,of[23].fecha1,of[23].fecha2,of[23].npersona,of[23].cod,of[23].aero1, of[23].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################25 


def MECGYE (update,context):
    global vul,  avi
    vul =Viaje(of[24].aerolinea,of[24].origen,of[24].destino,of[24].duracion,of[24].precio,of[24].fecha1,of[24].fecha2,of[24].npersona,of[24].cod,of[24].aero1, of[24].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################26 


def MECUIO (update,context):
    global vul,  avi
    vul =Viaje(of[25].aerolinea,of[25].origen,of[25].destino,of[25].duracion,of[25].precio,of[25].fecha1,of[25].fecha2,of[25].npersona,of[25].cod,of[25].aero1, of[25].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################27 


def MECCUE (update,context):
    global vul,  avi
    vul =Viaje(of[26].aerolinea,of[26].origen,of[26].destino,of[26].duracion,of[26].precio,of[26].fecha1,of[26].fecha2,of[26].npersona,of[26].cod,of[26].aero1, of[26].aero2)
    update.message.reply_text(
      "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################28 


def GPSGYE (update,context):
    global vul,  avi
    vul =Viaje(of[27].aerolinea,of[27].origen,of[27].destino,of[27].duracion,of[27].precio,of[27].fecha1,of[27].fecha2,of[27].npersona,of[27].cod,of[27].aero1, of[27].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################29 


def GPSCUE (update,context):
    global vul,  avi
    vul =Viaje(of[28].aerolinea,of[28].origen,of[28].destino,of[28].duracion,of[28].precio,of[28].fecha1,of[28].fecha2,of[28].npersona,of[28].cod,of[28].aero1, of[28].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################30 


def GPSUIO (update,context):
    global vul, avi
    vul =Viaje(of[29].aerolinea,of[29].origen,of[29].destino,of[29].duracion,of[29].precio,of[29].fecha1,of[29].fecha2,of[29].npersona,of[29].cod,of[29].aero1, of[29].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################31 


def GYEPEK (update,context):
    global vul,  avi
    vul =Viaje(of[30].aerolinea,of[30].origen,of[30].destino,of[30].duracion,of[30].precio,of[30].fecha1,of[30].fecha2,of[30].npersona,of[30].cod,of[30].aero1, of[30].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################32 


def CUEPEK (update,context):
    global vul,  avi
    vul =Viaje(of[31].aerolinea,of[31].origen,of[31].destino,of[31].duracion,of[31].precio,of[31].fecha1,of[31].fecha2,of[31].npersona,of[31].cod,of[31].aero1, of[31].aero2)
    update.message.reply_text(
        "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################33 


def CUEBOG  (update,context):
    global vul,  avi
    vul =Viaje(of[32].aerolinea,of[32].origen,of[32].destino,of[32].duracion,of[32].precio,of[32].fecha1,of[32].fecha2,of[32].npersona,of[32].cod,of[32].aero1, of[32].aero2)
    update.message.reply_text(
        "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################34 


def CUEMEC (update,context):
    global vul,  avi
    vul =Viaje(of[33].aerolinea,of[33].origen,of[33].destino,of[33].duracion,of[33].precio,of[33].fecha1,of[33].fecha2,of[33].npersona,of[33].cod,of[33].aero1, of[33].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################35 


def GYENRT (update,context):
    global vul,  avi
    vul =Viaje(of[34].aerolinea,of[34].origen,of[34].destino,of[34].duracion,of[34].precio,of[34].fecha1,of[34].fecha2,of[34].npersona,of[34].cod,of[34].aero1, of[34].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################36 


def GYEEWR (update,context):
    global vul,  avi
    vul =Viaje(of[35].aerolinea,of[35].origen,of[35].destino,of[35].duracion,of[35].precio,of[35].fecha1,of[35].fecha2,of[35].npersona,of[35].cod,of[35].aero1, of[35].aero2)
    update.message.reply_text(
       "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################37 


def CUEEWR (update,context):
    global vul, avi
    vul =Viaje(of[36].aerolinea,of[36].origen,of[36].destino,of[36].duracion,of[36].precio,of[36].fecha1,of[36].fecha2,of[36].npersona,of[36].cod,of[36].aero1, of[36].aero2)
    update.message.reply_text(
        "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################38 


def GYEMEL (update,context):
    global vul,  avi
    vul =Viaje(of[37].aerolinea,of[37].origen,of[37].destino,of[37].duracion,of[37].precio,of[37].fecha1,of[37].fecha2,of[37].npersona,of[37].cod,of[37].aero1, of[37].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia

 
##############################################################################################################39 


def GYELIM (update,context):
    global vul,  avi
    vul =Viaje(of[38].aerolinea,of[38].origen,of[38].destino,of[38].duracion,of[38].precio,of[38].fecha1,of[38].fecha2,of[38].npersona,of[38].cod,of[38].aero1, of[38].aero2)
    update.message.reply_text(
         "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################40 


def GYEODS (update,context):
    global vul,  avi
    vul =Viaje(of[39].aerolinea,of[39].origen,of[39].destino,of[39].duracion,of[39].precio,of[39].fecha1,of[39].fecha2,of[39].npersona,of[39].cod,of[39].aero1, of[39].aero2)
    update.message.reply_text(
        "Cuidad de partida: "+ vul.origen + "\nAeropuerto Salida: " + vul.aero1 + "\nCuidad de destino: "+ vul.destino + "\nAeropuerto Destino: " + vul.aero2 
        + "\nAerolinea: " + vul.aerolinea + "\nPrecio: " + str(vul.precio) + "$" + "\nDuracion: " + vul.duracion)
    update.message.reply_text(
        "A continuacion escriba /fecha_de_ida (000-00-00)\n Ejemplo /fecha_de_ida 2021-02-20 ")  # año-mes-dia
    if avi == True:
        update.message.reply_text(
            "A continuacion escriba /fecha_de_vuelta (000-00-00)\n Ejemplo /fecha_de_vuelta 2021-03-20 ")  # año-mes-dia


##############################################################################################################


#__________________________________main____________________________________-#

def main():
    #CONTROLADOR DE TOKEN 
    updater = Updater(TOKEN)

    #REGUISTRO DE CONTROLADORES PARA EL BOT
    dp = updater.dispatcher

    # COMANDOS DE CONTROLADORES DEL BOT
    dp.add_handler(CommandHandler("start", start))
    dp.add_handler(CommandHandler("regresar", start))
    dp.add_handler(CommandHandler("LIST",Listar))
    dp.add_handler(CommandHandler("BUY_TICKET", Ida))
    dp.add_handler(CommandHandler("BUYRT_TICKET", IdaVuelta))
    dp.add_handler(CommandHandler("asiento", nasiento, pass_args=True))
    dp.add_handler(CommandHandler("fecha_de_ida",Fecha1, pass_args=True))
    dp.add_handler(CommandHandler("fecha_de_vuelta", Fecha2, pass_args=True))
    dp.add_handler(CommandHandler("SEARCHD", bc, pass_args=True))
    dp.add_handler(CommandHandler("Reserva", Reserva))
    dp.add_handler(CommandHandler("cedulaR", Reserva, pass_args=True)) 
    dp.add_handler(CommandHandler("cedula", id, pass_args=True))
    dp.add_handler(CommandHandler("HELP", ayuda))
    dp.add_handler(CommandHandler("Nombre",Nombre, pass_args=True))
    dp.add_handler(CommandHandler("Apellido",Apellido, pass_args=True))
    dp.add_handler(CommandHandler("Busquedaciudad", Busquedaciudad,pass_args=True))
    dp.add_handler(CommandHandler("Busquedaiata", Busquedaiata,pass_args=True))
    dp.add_handler(CommandHandler("Busquedaaeropuerto", Busquedaaeropuerto,pass_args=True))
    dp.add_handler(CommandHandler("LIST_IATA",ListarIATA))
    dp.add_handler(CommandHandler("GYEUIO", GYEUIO))#1
    dp.add_handler(CommandHandler("GYEUIO", GYEUIO))#2
    dp.add_handler(CommandHandler("GYECUE", GYECUE))#3
    dp.add_handler(CommandHandler("GYEMEC", GYEMEC))#4
    dp.add_handler(CommandHandler("GYEGPS", GYEGPS))#5
    dp.add_handler(CommandHandler("GYEEZE", GYEEZE))#6
    dp.add_handler(CommandHandler("GYECOR", GYECOR))#7
    dp.add_handler(CommandHandler("GYEGRU", GYEGRU))#8
    dp.add_handler(CommandHandler("GYEMEX", GYEMEX))#9
    dp.add_handler(CommandHandler("UIOBOG", UIOBOG))#10
    dp.add_handler(CommandHandler("UIOMEX", UIOMEX))#11
    dp.add_handler(CommandHandler("UIOYYZ", UIOYYZ))#12
    dp.add_handler(CommandHandler("UIOSVO", UIOSVO))#13
    dp.add_handler(CommandHandler("UIORMU", UIORMU))#14
    dp.add_handler(CommandHandler("CUEGIG", CUEGIG))#15
    dp.add_handler(CommandHandler("CUECCS", CUECCS))#16
    dp.add_handler(CommandHandler("CUEMTY", CUEMTY))#17
    dp.add_handler(CommandHandler("CUEMEX", CUEMEX))#18
    dp.add_handler(CommandHandler("CUEUIO", CUEUIO))#19
    dp.add_handler(CommandHandler("GYEMIA", GYEMIA))#20
    dp.add_handler(CommandHandler("GYEMAH", GYEMAH))#21
    dp.add_handler(CommandHandler("GYEMDE", GYEMDE))#22
    dp.add_handler(CommandHandler("GYESVO", GYESVO))#23
    dp.add_handler(CommandHandler("GYEYUL", GYEYUL))#24
    dp.add_handler(CommandHandler("MECGYE", MECGYE))#25
    dp.add_handler(CommandHandler("MECUIO", MECUIO))#26
    dp.add_handler(CommandHandler("MECCUE", MECCUE))#27
    dp.add_handler(CommandHandler("GPSGYE", GPSGYE))#28
    dp.add_handler(CommandHandler("GPSCUE", GPSCUE))#29
    dp.add_handler(CommandHandler("GPSUIO", GPSUIO))#30
    dp.add_handler(CommandHandler("GYEPEK", GYEPEK))#31
    dp.add_handler(CommandHandler("CUEPEK", CUEPEK))#32
    dp.add_handler(CommandHandler("CUEBOG", CUEBOG))#33
    dp.add_handler(CommandHandler("CUEMEC", CUEMEC))#34
    dp.add_handler(CommandHandler("GYENRT", GYENRT))#35
    dp.add_handler(CommandHandler("GYEEWR", GYEEWR))#36
    dp.add_handler(CommandHandler("CUEEWR", CUEEWR))#37
    dp.add_handler(CommandHandler("GYEMEL", GYEMEL))#38
    dp.add_handler(CommandHandler("GYELIM", GYELIM))#39
    dp.add_handler(CommandHandler("GYEODS", GYEODS))#40

    
    # CONTROLADOR DE COMANDO INVALIDO
    dp.add_handler(MessageHandler(Filters.text, mensaje_nocomando))
   
    # INICIO DEL BOT
    updater.start_polling()
    # ACTUALIZACIÓN DEL ESTADO DE LOS MENSAJES EN ESPERA
    updater.idle()
    
if __name__ == '__main__':
    main()


# Fin del Codigo
